# %%
import sys
# !{sys.executable} -m pip install opencv-python

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('./Images/office_noisy.png')
#uncomment to print all the elements of the image data 
#np.set_printoptions(threshold=sys.maxsize)


sigmaSet = {0.5, 1, 2, 5, 10, 50}

images ={}    #Initialising the resultant image 
images['Noisy Image'] = img

for σ in sorted(sigmaSet):
    images['Gaussian with σ ='+str(σ)] = cv2.GaussianBlur(img, (5,5), σ, borderType=cv2.BORDER_CONSTANT)

for key, value in images.items():
   
    plt.figure()
    plt.subplot(1, 2, 1)
    plt.imshow(value, 'gray') 
    plt.title(key)
    plt.xticks([]),plt.yticks([])
    
    
fignum = 0
fig = plt.figure()
for σ in sorted(sigmaSet):
        fignum += 1
        print(σ, fignum)
        psnr_val = "{:.2f}".format(psnr_cal.PSNR(io, ion))
        ax = fig.add_subplot(230 + fignum)
        im = ax.imshow(ion.copy(), cmap='gray', vmin=0, vmax=255)
        ax.set_axis_off()
        ax.set_title(f'T= {m}\n PSNR = {psnr_val}, \u03BB = {landa}')
        print("PSNR = ", psnr_val)
    ion0, ion = dif_do_step.do_timestep_persona_malek(ion0, ion, dt, dx, dy, landa)
    
fig.subplots_adjust(right=0.85)

plt.show()
